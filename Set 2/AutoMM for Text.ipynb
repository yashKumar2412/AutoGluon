# %%
# !pip install -q autogluon.multimodal

# %%
# !pip install -q autogluon
# !pip install -q torch torchvision torchaudio transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.1/312.1 kB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.2/148.2 kB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 60.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 67.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.0/410.0 kB 27.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.3/812.3 kB 41.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 95.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 66.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 70.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 55.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.5 MB/s eta 0:00:00

# %%
# !pip uninstall -q torch torchaudio -y
# !pip install -q torch torchvision torchaudio

# %%
# !pip install -q autogluon --upgrade

# %%
import os
os.kill(os.getpid(), 9)

# %%
# %matplotlib inline

import numpy as np
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')
np.random.seed(123)

# %%
from autogluon.core.utils.loaders import load_pd
train_data = load_pd.load('https://autogluon-text.s3-accelerate.amazonaws.com/glue/sst/train.parquet')
test_data = load_pd.load('https://autogluon-text.s3-accelerate.amazonaws.com/glue/sst/dev.parquet')
subsample_size = 1000  # subsample data for faster demo, try setting this to larger values
train_data = train_data.sample(n=subsample_size, random_state=0)
train_data.head(10)
# Out:
#                                                 sentence  label
# 43787                 very pleasing at its best moments       1
# 16159  , american chai is enough to make you put away...      0
# 59015  too much like an infomercial for ram dass 's l...      0
# 5108                         a stirring visual sequence       1
# 67052                           cool visual backmasking       1
# 35938                                       hard ground       0
# 49879  the striking , quietly vulnerable personality ...      1
# 51591  pan nalin 's exposition is beautiful and myste...      1
# 56780                                 wonderfully loopy       1
# 28518                        most beautiful , evocative       1

# %%
from autogluon.multimodal import MultiModalPredictor
import uuid
model_path = f"./tmp/{uuid.uuid4().hex}-automm_sst"
predictor = MultiModalPredictor(label='label', eval_metric='acc', path=model_path)
predictor.fit(train_data, time_limit=180)
# Out:
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Thu Jun 27 21:05:47 UTC 2024
# CPU Count:          2
# Pytorch Version:    2.3.1+cu121
# CUDA Version:       12.1
# Memory Avail:       10.44 GB / 12.67 GB (82.3%)
# Disk Space Avail:   65.92 GB / 112.64 GB (58.5%)
# ===================================================
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [1, 0]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
#
# AutoMM starts to create your model. ✨✨✨
#
# To track the learning progress, you can open a terminal and launch Tensorboard:
#     ```shell
#     # Assume you have installed tensorboard
#     tensorboard --logdir /content/tmp/499fddac680f4624b99af7c6c566a4a3-automm_sst
#     ```
#
# INFO: Seed set to 0
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# GPU Count: 1
# GPU Count to be Used: 1
# GPU 0 Name: Tesla T4
# GPU 0 Memory: 0.25GB/15.0GB (Used/Total)
#
# INFO: Using 16bit Automatic Mixed Precision (AMP)
# INFO: GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name              | Type                         | Params | Mode
# ---------------------------------------------------------------------------
# 0 | model             | HFAutoModelForTextPrediction | 108 M  | train
# 1 | validation_metric | MulticlassAccuracy           | 0      | train
# 2 | loss_func         | CrossEntropyLoss             | 0      | train
# ---------------------------------------------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 435.573   Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: Epoch 0, global step 3: 'val_acc' reached 0.54500 (best 0.54500), saving model to '/content/tmp/499fddac680f4624b99af7c6c566a4a3-automm_sst/epoch=0-step=3.ckpt' as top 3
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: Epoch 0, global step 7: 'val_acc' reached 0.62500 (best 0.62500), saving model to '/content/tmp/499fddac680f4624b99af7c6c566a4a3-automm_sst/epoch=0-step=7.ckpt' as top 3
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: Epoch 1, global step 10: 'val_acc' reached 0.70500 (best 0.70500), saving model to '/content/tmp/499fddac680f4624b99af7c6c566a4a3-automm_sst/epoch=1-step=10.ckpt' as top 3
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: Epoch 1, global step 14: 'val_acc' reached 0.84000 (best 0.84000), saving model to '/content/tmp/499fddac680f4624b99af7c6c566a4a3-automm_sst/epoch=1-step=14.ckpt' as top 3
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: Epoch 2, global step 17: 'val_acc' reached 0.86000 (best 0.86000), saving model to '/content/tmp/499fddac680f4624b99af7c6c566a4a3-automm_sst/epoch=2-step=17.ckpt' as top 3
# INFO: Time limit reached. Elapsed time is 0:03:13. Signaling Trainer to stop.
# Validation: |          | 0/? [00:00<?, ?it/s]
# Start to fuse 3 checkpoints via the greedy soup algorithm.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# AutoMM has created your model. 🎉🎉🎉
#
# To load the model, use the code below:
#     ```python
#     from autogluon.multimodal import MultiModalPredictor
#     predictor = MultiModalPredictor.load("/content/tmp/499fddac680f4624b99af7c6c566a4a3-automm_sst")
#     ```
#
# If you are not satisfied with the model, try to increase the training time,
# adjust the hyperparameters (https://auto.gluon.ai/stable/tutorials/multimodal/advanced_topics/customization.html),
# or post issues on GitHub (https://github.com/autogluon/autogluon/issues).

# %%
test_score = predictor.evaluate(test_data)
print(test_score)
# Out:
# Predicting: |          | 0/? [00:00<?, ?it/s]
# {'acc': 0.8772935779816514}

# %%
test_score = predictor.evaluate(test_data, metrics=['acc', 'f1'])
print(test_score)
# Out:
# Predicting: |          | 0/? [00:00<?, ?it/s]
# {'acc': 0.8772935779816514, 'f1': 0.8796400449943758}

# %%
sentence1 = "it's a charming and often affecting journey."
sentence2 = "It's slow, very, very, very slow."
predictions = predictor.predict({'sentence': [sentence1, sentence2]})
print('"Sentence":', sentence1, '"Predicted Sentiment":', predictions[0])
print('"Sentence":', sentence2, '"Predicted Sentiment":', predictions[1])
# Out:
# Predicting: |          | 0/? [00:00<?, ?it/s]
# "Sentence": it's a charming and often affecting journey. "Predicted Sentiment": 1
# "Sentence": It's slow, very, very, very slow. "Predicted Sentiment": 0

# %%
probs = predictor.predict_proba({'sentence': [sentence1, sentence2]})
print('"Sentence":', sentence1, '"Predicted Class-Probabilities":', probs[0])
print('"Sentence":', sentence2, '"Predicted Class-Probabilities":', probs[1])
# Out:
# Predicting: |          | 0/? [00:00<?, ?it/s]
# "Sentence": it's a charming and often affecting journey. "Predicted Class-Probabilities": [0.0070664  0.99293363]
# "Sentence": It's slow, very, very, very slow. "Predicted Class-Probabilities": [0.88478804 0.11521199]

# %%
test_predictions = predictor.predict(test_data)
test_predictions.head()
# Out:
# Predicting: |          | 0/? [00:00<?, ?it/s]
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# Name: label, dtype: int64

# %%
loaded_predictor = MultiModalPredictor.load(model_path)
loaded_predictor.predict_proba({'sentence': [sentence1, sentence2]})
# Out:
# Load pretrained checkpoint: /content/tmp/499fddac680f4624b99af7c6c566a4a3-automm_sst/model.ckpt
# Predicting: |          | 0/? [00:00<?, ?it/s]
# array([[0.0070664 , 0.99293363],
#        [0.88478804, 0.11521199]], dtype=float32)

# %%
new_model_path = f"./tmp/{uuid.uuid4().hex}-automm_sst"
loaded_predictor.save(new_model_path)
loaded_predictor2 = MultiModalPredictor.load(new_model_path)
loaded_predictor2.predict_proba({'sentence': [sentence1, sentence2]})
# Out:
# Load pretrained checkpoint: /content/tmp/6de2c04dabd34b46ad901042fb49edab-automm_sst/model.ckpt
# Predicting: |          | 0/? [00:00<?, ?it/s]
# array([[0.0070664 , 0.99293363],
#        [0.88478804, 0.11521199]], dtype=float32)

# %%
embeddings = predictor.extract_embedding(test_data)
print(embeddings.shape)
# Out:
# Predicting: |          | 0/? [00:00<?, ?it/s]
# (872, 768)

# %%
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=2, random_state=123).fit_transform(embeddings)
for val, color in [(0, 'red'), (1, 'blue')]:
    idx = (test_data['label'].to_numpy() == val).nonzero()
    plt.scatter(X_embedded[idx, 0], X_embedded[idx, 1], c=color, label=f'label={val}')
plt.legend(loc='best')

# %%
sts_train_data = load_pd.load('https://autogluon-text.s3-accelerate.amazonaws.com/glue/sts/train.parquet')[['sentence1', 'sentence2', 'score']]
sts_test_data = load_pd.load('https://autogluon-text.s3-accelerate.amazonaws.com/glue/sts/dev.parquet')[['sentence1', 'sentence2', 'score']]
sts_train_data.head(10)
# Out:
# Loaded data from: https://autogluon-text.s3-accelerate.amazonaws.com/glue/sts/train.parquet | Columns = 4 / 4 | Rows = 5749 -> 5749
# Loaded data from: https://autogluon-text.s3-accelerate.amazonaws.com/glue/sts/dev.parquet | Columns = 4 / 4 | Rows = 1500 -> 1500
#                                        sentence1  \
# 0                         A plane is taking off.
# 1                A man is playing a large flute.
# 2  A man is spreading shreded cheese on a pizza.
# 3                   Three men are playing chess.
# 4                    A man is playing the cello.
# 5                         Some men are fighting.
# 6                              A man is smoking.
# 7                  The man is playing the piano.
# 8      A man is playing on a guitar and singing.
# 9  A person is throwing a cat on to the ceiling.
#
#                                            sentence2  score
# 0                        An air plane is taking off.   5.00
# 1                          A man is playing a flute.   3.80
# 2  A man is spreading shredded cheese on an uncoo...   3.80
# 3                         Two men are playing chess.   2.60
# 4                 A man seated is playing the cello.   4.25
# 5                              Two men are fighting.   4.25
# 6                                  A man is skating.   0.50
# 7                     The man is playing the guitar.   1.60
# 8  A woman is playing an acoustic guitar and sing...   2.20
# 9              A person throws a cat on the ceiling.   5.00

# %%
print('Min score=', min(sts_train_data['score']), ', Max score=', max(sts_train_data['score']))
# Out:
# Min score= 0.0 , Max score= 5.0

# %%
sts_model_path = f"./tmp/{uuid.uuid4().hex}-automm_sts"
predictor_sts = MultiModalPredictor(label='score', path=sts_model_path)
predictor_sts.fit(sts_train_data, time_limit=600)
# Out:
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Thu Jun 27 21:05:47 UTC 2024
# CPU Count:          2
# Pytorch Version:    2.3.1+cu121
# CUDA Version:       12.1
# Memory Avail:       7.00 GB / 12.67 GB (55.2%)
# Disk Space Avail:   64.65 GB / 112.64 GB (57.4%)
# ===================================================
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and label-values can't be converted to int).
# 	Label info (max, min, mean, stddev): (5.0, 0.0, 2.701, 1.4644)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
#
# AutoMM starts to create your model. ✨✨✨
#
# To track the learning progress, you can open a terminal and launch Tensorboard:
#     ```shell
#     # Assume you have installed tensorboard
#     tensorboard --logdir /content/tmp/362a5699fcc54dc49572c242908a9147-automm_sts
#     ```
#
# INFO: Seed set to 0
# GPU Count: 1
# GPU Count to be Used: 1
# GPU 0 Name: Tesla T4
# GPU 0 Memory: 0.4GB/15.0GB (Used/Total)
#
# INFO: Using 16bit Automatic Mixed Precision (AMP)
# INFO: GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name              | Type                         | Params | Mode
# ---------------------------------------------------------------------------
# 0 | model             | HFAutoModelForTextPrediction | 108 M  | train
# 1 | validation_metric | MeanSquaredError             | 0      | train
# 2 | loss_func         | MSELoss                      | 0      | train
# ---------------------------------------------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 435.570   Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: Epoch 0, global step 20: 'val_rmse' reached 0.59602 (best 0.59602), saving model to '/content/tmp/362a5699fcc54dc49572c242908a9147-automm_sts/epoch=0-step=20.ckpt' as top 3
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: Epoch 0, global step 40: 'val_rmse' reached 0.50744 (best 0.50744), saving model to '/content/tmp/362a5699fcc54dc49572c242908a9147-automm_sts/epoch=0-step=40.ckpt' as top 3
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: Epoch 1, global step 61: 'val_rmse' reached 0.46053 (best 0.46053), saving model to '/content/tmp/362a5699fcc54dc49572c242908a9147-automm_sts/epoch=1-step=61.ckpt' as top 3
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: Epoch 1, global step 81: 'val_rmse' reached 0.44780 (best 0.44780), saving model to '/content/tmp/362a5699fcc54dc49572c242908a9147-automm_sts/epoch=1-step=81.ckpt' as top 3
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: Epoch 2, global step 102: 'val_rmse' reached 0.44587 (best 0.44587), saving model to '/content/tmp/362a5699fcc54dc49572c242908a9147-automm_sts/epoch=2-step=102.ckpt' as top 3
# INFO: Time limit reached. Elapsed time is 0:10:00. Signaling Trainer to stop.
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: Epoch 2, global step 121: 'val_rmse' was not in top 3
# Start to fuse 3 checkpoints via the greedy soup algorithm.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# AutoMM has created your model. 🎉🎉🎉
#
# To load the model, use the code below:
#     ```python
#     from autogluon.multimodal import MultiModalPredictor
#     predictor = MultiModalPredictor.load("/content/tmp/362a5699fcc54dc49572c242908a9147-automm_sts")
#     ```
#
# If you are not satisfied with the model, try to increase the training time,
# adjust the hyperparameters (https://auto.gluon.ai/stable/tutorials/multimodal/advanced_topics/customization.html),
# or post issues on GitHub (https://github.com/autogluon/autogluon/issues).

# %%
test_score = predictor_sts.evaluate(sts_test_data, metrics=['rmse', 'pearsonr', 'spearmanr'])
print('RMSE = {:.2f}'.format(test_score['rmse']))
print('PEARSONR = {:.4f}'.format(test_score['pearsonr']))
print('SPEARMANR = {:.4f}'.format(test_score['spearmanr']))
# Out:
# Predicting: |          | 0/? [00:00<?, ?it/s]
# RMSE = 0.68
# PEARSONR = 0.8946
# SPEARMANR = 0.8958

# %%
sentences = ['The child is riding a horse.',
             'The young boy is riding a horse.',
             'The young man is riding a horse.',
             'The young man is riding a bicycle.']

score1 = predictor_sts.predict({'sentence1': [sentences[0]],
                                'sentence2': [sentences[1]]}, as_pandas=False)

score2 = predictor_sts.predict({'sentence1': [sentences[0]],
                                'sentence2': [sentences[2]]}, as_pandas=False)

score3 = predictor_sts.predict({'sentence1': [sentences[0]],
                                'sentence2': [sentences[3]]}, as_pandas=False)
print(score1, score2, score3)
# Out:
# Predicting: |          | 0/? [00:00<?, ?it/s]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# 3.846329 3.0081768 1.2824436
