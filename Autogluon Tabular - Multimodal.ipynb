# %%
# !pip install -q autogluon
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 9.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 23.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.8/234.8 kB 19.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.4/63.4 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.0/428.0 kB 35.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.1/312.1 kB 27.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.2/148.2 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 70.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 22.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.1/139.1 kB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 65.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.5/808.5 kB 46.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 31.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.0/410.0 kB 25.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.3/812.3 kB 43.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.1/65.1 MB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 71.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 110.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 50.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 111.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 76.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 51.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.1/806.1 kB 50.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 112.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 97.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 76.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 29.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 69.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 69.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 74.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 49.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 73.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 16.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 89.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 31.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 81.6 MB/s eta 0:00:00
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.4.15 requires scikit-image>=0.21.0, but you have scikit-image 0.20.0 which is incompatible.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# osqp 0.6.7.post0 requires scipy!=1.12.0,>=0.13.2, but you have scipy 1.12.0 which is incompatible.
# torchaudio 2.4.1+cu121 requires torch==2.4.1, but you have torch 2.3.1 which is incompatible.

# %%
download_dir = './ag_petfinder_tutorial'
zip_file = 'https://automl-mm-bench.s3.amazonaws.com/petfinder_kaggle.zip'

# %%
from autogluon.core.utils.loaders import load_zip
load_zip.unzip(zip_file, unzip_dir=download_dir)
# Out:
# Downloading ./ag_petfinder_tutorial/file.zip from https://automl-mm-bench.s3.amazonaws.com/petfinder_kaggle.zip...
# 100%|██████████| 2.00G/2.00G [01:02<00:00, 32.1MiB/s]

# %%
import os
os.listdir(download_dir)
# Out:
# ['petfinder_processed', 'file.zip']

# %%
dataset_path = download_dir + '/petfinder_processed'
os.listdir(dataset_path)
# Out:
# ['test.csv', 'train_images', 'train.csv', 'dev.csv', 'test_images']

# %%
os.listdir(dataset_path + '/train_images')[:10]
# Out:
# ['98caf2809-3.jpg',
#  '9edb2d79a-4.jpg',
#  'f982548b8-2.jpg',
#  '54b6c1d72-15.jpg',
#  '04a555b91-2.jpg',
#  '0ffe99b25-1.jpg',
#  '14c70761a-1.jpg',
#  '7a23bdbdc-2.jpg',
#  'dcd75bfdb-1.jpg',
#  'a99a82e6d-5.jpg']

# %%
import pandas as pd

train_data = pd.read_csv(f'{dataset_path}/train.csv', index_col=0)
test_data = pd.read_csv(f'{dataset_path}/dev.csv', index_col=0)

# %%
train_data.head(3)
# Out:
#        Type     Name  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  \
# 10721     1     Elbi    2     307     307       2       5       0       0
# 13114     2  Darling    4     266       0       1       1       0       0
# 13194     1     Wolf    3     307       0       1       1       2       0
#
#        MaturitySize  ...  Quantity  Fee  State  \
# 10721             3  ...         1    0  41336
# 13114             2  ...         1    0  41401
# 13194             2  ...         1    0  41332
#
#                               RescuerID  VideoAmt  \
# 10721  e9a86209c54f589ba72c345364cf01aa         0
# 13114  01f954cdf61526daf3fbeb8a074be742         0
# 13194  6e19409f2847326ce3b6d0cec7e42f81         0
#
#                                              Description      PetID  PhotoAmt  \
# 10721             I'm looking for people to adopt my dog  e4b90955c       4.0
# 13114  Darling was born at the back lane of Jalan Alo...  a0c1384d1       5.0
# 13194  I found Wolf about a month ago stuck in a drai...  cf357f057       7.0
#
#       AdoptionSpeed                                             Images
# 10721             4  train_images/e4b90955c-1.jpg;train_images/e4b9...
# 13114             3  train_images/a0c1384d1-1.jpg;train_images/a0c1...
# 13194             4  train_images/cf357f057-1.jpg;train_images/cf35...
#
# [3 rows x 25 columns]

# %%
label = 'AdoptionSpeed'
image_col = 'Images'

# %%
train_data[image_col].iloc[0]
# Out:
# 'train_images/e4b90955c-1.jpg;train_images/e4b90955c-2.jpg;train_images/e4b90955c-3.jpg;train_images/e4b90955c-4.jpg'

# %%
train_data[image_col] = train_data[image_col].apply(lambda ele: ele.split(';')[0])
test_data[image_col] = test_data[image_col].apply(lambda ele: ele.split(';')[0])

train_data[image_col].iloc[0]
# Out:
# 'train_images/e4b90955c-1.jpg'

# %%
def path_expander(path, base_folder):
    path_l = path.split(';')
    return ';'.join([os.path.abspath(os.path.join(base_folder, path)) for path in path_l])

train_data[image_col] = train_data[image_col].apply(lambda ele: path_expander(ele, base_folder=dataset_path))
test_data[image_col] = test_data[image_col].apply(lambda ele: path_expander(ele, base_folder=dataset_path))

train_data[image_col].iloc[0]
# Out:
# '/content/ag_petfinder_tutorial/petfinder_processed/train_images/e4b90955c-1.jpg'

# %%
train_data.head(3)
# Out:
#        Type     Name  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  \
# 10721     1     Elbi    2     307     307       2       5       0       0
# 13114     2  Darling    4     266       0       1       1       0       0
# 13194     1     Wolf    3     307       0       1       1       2       0
#
#        MaturitySize  ...  Quantity  Fee  State  \
# 10721             3  ...         1    0  41336
# 13114             2  ...         1    0  41401
# 13194             2  ...         1    0  41332
#
#                               RescuerID  VideoAmt  \
# 10721  e9a86209c54f589ba72c345364cf01aa         0
# 13114  01f954cdf61526daf3fbeb8a074be742         0
# 13194  6e19409f2847326ce3b6d0cec7e42f81         0
#
#                                              Description      PetID  PhotoAmt  \
# 10721             I'm looking for people to adopt my dog  e4b90955c       4.0
# 13114  Darling was born at the back lane of Jalan Alo...  a0c1384d1       5.0
# 13194  I found Wolf about a month ago stuck in a drai...  cf357f057       7.0
#
#       AdoptionSpeed                                             Images
# 10721             4  /content/ag_petfinder_tutorial/petfinder_proce...
# 13114             3  /content/ag_petfinder_tutorial/petfinder_proce...
# 13194             4  /content/ag_petfinder_tutorial/petfinder_proce...
#
# [3 rows x 25 columns]

# %%
example_row = train_data.iloc[1]

example_row
# Out:
# Type                                                             2
# Name                                                       Darling
# Age                                                              4
# Breed1                                                         266
# Breed2                                                           0
# Gender                                                           1
# Color1                                                           1
# Color2                                                           0
# Color3                                                           0
# MaturitySize                                                     2
# FurLength                                                        1
# Vaccinated                                                       2
# Dewormed                                                         2
# Sterilized                                                       2
# Health                                                           1
# Quantity                                                         1
# Fee                                                              0
# State                                                        41401
# RescuerID                         01f954cdf61526daf3fbeb8a074be742
# VideoAmt                                                         0
# Description      Darling was born at the back lane of Jalan Alo...
# PetID                                                    a0c1384d1
# PhotoAmt                                                       5.0
# AdoptionSpeed                                                    3
# Images           /content/ag_petfinder_tutorial/petfinder_proce...
# Name: 13114, dtype: object

# %%
example_row['Description']
# Out:
# 'Darling was born at the back lane of Jalan Alor and was foster by a feeder. All his siblings had died of accident. His mother and grandmother had just been spayed. Darling make a great condo/apartment cat. He love to play a lot. He would make a great companion for someone looking for a cat to love.'

# %%
example_image = example_row['Images']

from IPython.display import Image, display
pil_img = Image(filename=example_image)
display(pil_img)

# %%
train_data = train_data.sample(500, random_state=0)

# %%
from autogluon.tabular import FeatureMetadata
feature_metadata = FeatureMetadata.from_df(train_data)

print(feature_metadata)
# Out:
# ('float', [])        :  1 | ['PhotoAmt']
# ('int', [])          : 19 | ['Type', 'Age', 'Breed1', 'Breed2', 'Gender', ...]
# ('object', [])       :  4 | ['Name', 'RescuerID', 'PetID', 'Images']
# ('object', ['text']) :  1 | ['Description']

# %%
feature_metadata = feature_metadata.add_special_types({image_col: ['image_path']})

print(feature_metadata)
# Out:
# ('float', [])              :  1 | ['PhotoAmt']
# ('int', [])                : 19 | ['Type', 'Age', 'Breed1', 'Breed2', 'Gender', ...]
# ('object', [])             :  3 | ['Name', 'RescuerID', 'PetID']
# ('object', ['image_path']) :  1 | ['Images']
# ('object', ['text'])       :  1 | ['Description']

# %%
from autogluon.tabular.configs.hyperparameter_configs import get_hyperparameter_config
hyperparameters = get_hyperparameter_config('multimodal')

hyperparameters
# Out:
# {'NN_TORCH': {},
#  'GBM': [{},
#   {'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}},
#   'GBMLarge'],
#  'CAT': {},
#  'XGB': {},
#  'AG_AUTOMM': {},
#  'VW': {}}

# %%
from autogluon.tabular import TabularPredictor
predictor = TabularPredictor(label=label).fit(
    train_data=train_data,
    hyperparameters=hyperparameters,
    feature_metadata=feature_metadata,
    presets='high_quality',
    time_limit=600
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20240930_231941"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Thu Jun 27 21:05:47 UTC 2024
# CPU Count:          2
# Memory Avail:       11.30 GB / 12.67 GB (89.1%)
# Disk Space Avail:   62.82 GB / 112.64 GB (55.8%)
# ===================================================
# Presets specified: ['high_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 150s of the 600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-09-30 23:19:47,686	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "AutogluonModels/ag-20240930_231941/ds_sub_fit/sub_fit_ho"
# (_dystack pid=3341) Running DyStack sub-fit ...
# (_dystack pid=3341) Beginning AutoGluon training ... Time limit = 141s
# (_dystack pid=3341) AutoGluon will save models to "AutogluonModels/ag-20240930_231941/ds_sub_fit/sub_fit_ho"
# (_dystack pid=3341) Train Data Rows:    444
# (_dystack pid=3341) Train Data Columns: 24
# (_dystack pid=3341) Label Column:       AdoptionSpeed
# (_dystack pid=3341) Problem Type:       multiclass
# (_dystack pid=3341) Preprocessing data ...
# (_dystack pid=3341) Warning: Some classes in the training set have fewer than 10 examples. AutoGluon will only keep 4 out of 5 classes for training and will not try to predict the rare classes. To keep more classes, increase the number of datapoints from these rare classes in the training data or reduce label_count_threshold.
# (_dystack pid=3341) Fraction of data from classes with at least 10 examples that will be kept for training models: 0.9797297297297297
# (_dystack pid=3341) Train Data Class Count: 4
# (_dystack pid=3341) Using Feature Generators to preprocess the data ...
# (_dystack pid=3341) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=3341) 	Available Memory:                    11021.08 MB
# (_dystack pid=3341) 	Train Data (Original)  Memory Usage: 0.35 MB (0.0% of available memory)
# (_dystack pid=3341) 	Stage 1 Generators:
# (_dystack pid=3341) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=3341) 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=3341) 	Stage 2 Generators:
# (_dystack pid=3341) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=3341) 	Stage 3 Generators:
# (_dystack pid=3341) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=3341) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=3341) 			Fitting RenameFeatureGenerator...
# (_dystack pid=3341) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=3341) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=3341) 		Fitting TextSpecialFeatureGenerator...
# (_dystack pid=3341) 			Fitting BinnedFeatureGenerator...
# (_dystack pid=3341) 			Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=3341) 		Fitting TextNgramFeatureGenerator...
# (_dystack pid=3341) 			Fitting CountVectorizer for text features: ['Description']
# (_dystack pid=3341) 			CountVectorizer fit with vocabulary size = 142
# (_dystack pid=3341) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=3341) 		Fitting IsNanFeatureGenerator...
# (_dystack pid=3341) 	Stage 4 Generators:
# (_dystack pid=3341) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=3341) 	Stage 5 Generators:
# (_dystack pid=3341) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=3341) 	Unused Original Features (Count: 1): ['PetID']
# (_dystack pid=3341) 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# (_dystack pid=3341) 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# (_dystack pid=3341) 		These features do not need to be present at inference time.
# (_dystack pid=3341) 		('object', []) : 1 | ['PetID']
# (_dystack pid=3341) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=3341) 		('float', [])              :  1 | ['PhotoAmt']
# (_dystack pid=3341) 		('int', [])                : 18 | ['Type', 'Age', 'Breed1', 'Breed2', 'Gender', ...]
# (_dystack pid=3341) 		('object', [])             :  2 | ['Name', 'RescuerID']
# (_dystack pid=3341) 		('object', ['image_path']) :  1 | ['Images']
# (_dystack pid=3341) 		('object', ['text'])       :  1 | ['Description']
# (_dystack pid=3341) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=3341) 		('category', [])                    :   2 | ['Name', 'RescuerID']
# (_dystack pid=3341) 		('category', ['text_as_category'])  :   1 | ['Description']
# (_dystack pid=3341) 		('float', [])                       :   1 | ['PhotoAmt']
# (_dystack pid=3341) 		('int', [])                         :  17 | ['Age', 'Breed1', 'Breed2', 'Gender', 'Color1', ...]
# (_dystack pid=3341) 		('int', ['binned', 'text_special']) :  20 | ['Description.char_count', 'Description.word_count', 'Description.capital_ratio', 'Description.lower_ratio', 'Description.digit_ratio', ...]
# (_dystack pid=3341) 		('int', ['bool'])                   :   1 | ['Type']
# (_dystack pid=3341) 		('int', ['text_ngram'])             : 143 | ['__nlp__.about', '__nlp__.active', '__nlp__.adopt', '__nlp__.adopter', '__nlp__.adoption', ...]
# (_dystack pid=3341) 		('object', ['image_path'])          :   1 | ['Images']
# (_dystack pid=3341) 		('object', ['text'])                :   1 | ['Description_raw_text']
# (_dystack pid=3341) 	1.7s = Fit runtime
# (_dystack pid=3341) 	23 features in original data used to generate 187 features in processed data.
# (_dystack pid=3341) 	Train Data (Processed) Memory Usage: 0.40 MB (0.0% of available memory)
# (_dystack pid=3341) Data preprocessing and feature engineering runtime = 1.72s ...
# (_dystack pid=3341) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=3341) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=3341) User-specified model hyperparameters to be fit:
# (_dystack pid=3341) {
# (_dystack pid=3341) 	'NN_TORCH': {},
# (_dystack pid=3341) 	'GBM': [{}, {'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, 'GBMLarge'],
# (_dystack pid=3341) 	'CAT': {},
# (_dystack pid=3341) 	'XGB': {},
# (_dystack pid=3341) 	'AG_AUTOMM': {},
# (_dystack pid=3341) 	'VW': {},
# (_dystack pid=3341) }
# (_dystack pid=3341) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=3341) Fitting 8 L1 models ...
# (_dystack pid=3341) Fitting model: LightGBM_BAG_L1 ... Training model for up to 92.98s of the 139.5s of remaining time.
# (_dystack pid=3341) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.33%)
# (_ray_fit pid=3492) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# (_ray_fit pid=3492) Dask dataframe query planning is disabled because dask-expr is not installed.
# (_ray_fit pid=3492)
# (_ray_fit pid=3492) You can install it with `pip install dask[dataframe]` or `conda install dask`.
# (_ray_fit pid=3492) This will raise in a future version.
# (_ray_fit pid=3492)
# (_ray_fit pid=3492)   warnings.warn(msg, FutureWarning)
# (_ray_fit pid=3577) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:  [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=3577) Dask dataframe query planning is disabled because dask-expr is not installed. [repeated 2x across cluster]
# (_ray_fit pid=3577)  [repeated 4x across cluster]
# (_ray_fit pid=3577) You can install it with `pip install dask[dataframe]` or `conda install dask`. [repeated 2x across cluster]
# (_ray_fit pid=3577) This will raise in a future version. [repeated 2x across cluster]
# (_ray_fit pid=3577)   warnings.warn(msg, FutureWarning) [repeated 2x across cluster]
# (_ray_fit pid=3666) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:  [repeated 2x across cluster]
# (_ray_fit pid=3666) Dask dataframe query planning is disabled because dask-expr is not installed. [repeated 2x across cluster]
# (_ray_fit pid=3666)  [repeated 4x across cluster]
# (_ray_fit pid=3666) You can install it with `pip install dask[dataframe]` or `conda install dask`. [repeated 2x across cluster]
# (_ray_fit pid=3666) This will raise in a future version. [repeated 2x across cluster]
# (_ray_fit pid=3666)   warnings.warn(msg, FutureWarning) [repeated 2x across cluster]
# (_ray_fit pid=3740) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:  [repeated 2x across cluster]
# (_ray_fit pid=3740) Dask dataframe query planning is disabled because dask-expr is not installed. [repeated 2x across cluster]
# (_ray_fit pid=3740)  [repeated 4x across cluster]
# (_ray_fit pid=3740) You can install it with `pip install dask[dataframe]` or `conda install dask`. [repeated 2x across cluster]
# (_ray_fit pid=3740) This will raise in a future version. [repeated 2x across cluster]
# (_ray_fit pid=3740)   warnings.warn(msg, FutureWarning) [repeated 2x across cluster]
# (_dystack pid=3341) 	0.377	 = Validation score   (accuracy)
# (_dystack pid=3341) 	26.11s	 = Training   runtime
# (_dystack pid=3341) 	0.06s	 = Validation runtime
# (_dystack pid=3341) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 64.39s of the 110.91s of remaining time.
# (_dystack pid=3341) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.35%)
# (_ray_fit pid=3834) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:  [repeated 2x across cluster]
# (_ray_fit pid=3834) Dask dataframe query planning is disabled because dask-expr is not installed. [repeated 2x across cluster]
# (_ray_fit pid=3834)  [repeated 4x across cluster]
# (_ray_fit pid=3834) You can install it with `pip install dask[dataframe]` or `conda install dask`. [repeated 2x across cluster]
# (_ray_fit pid=3834) This will raise in a future version. [repeated 2x across cluster]
# (_ray_fit pid=3834)   warnings.warn(msg, FutureWarning) [repeated 2x across cluster]
# (_ray_fit pid=3915) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:  [repeated 2x across cluster]
# (_ray_fit pid=3915) Dask dataframe query planning is disabled because dask-expr is not installed. [repeated 2x across cluster]
# (_ray_fit pid=3915)  [repeated 4x across cluster]
# (_ray_fit pid=3915) You can install it with `pip install dask[dataframe]` or `conda install dask`. [repeated 2x across cluster]
# (_ray_fit pid=3915) This will raise in a future version. [repeated 2x across cluster]
# (_ray_fit pid=3915)   warnings.warn(msg, FutureWarning) [repeated 2x across cluster]
# (_ray_fit pid=4004) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:  [repeated 2x across cluster]
# (_ray_fit pid=4004) Dask dataframe query planning is disabled because dask-expr is not installed. [repeated 2x across cluster]
# (_ray_fit pid=4004)  [repeated 4x across cluster]
# (_ray_fit pid=4004) You can install it with `pip install dask[dataframe]` or `conda install dask`. [repeated 2x across cluster]
# (_ray_fit pid=4004) This will raise in a future version. [repeated 2x across cluster]
# (_ray_fit pid=4004)   warnings.warn(msg, FutureWarning) [repeated 2x across cluster]
# (_ray_fit pid=4087) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:  [repeated 2x across cluster]
# (_ray_fit pid=4087) Dask dataframe query planning is disabled because dask-expr is not installed. [repeated 2x across cluster]
# (_ray_fit pid=4087)  [repeated 4x across cluster]
# (_ray_fit pid=4087) You can install it with `pip install dask[dataframe]` or `conda install dask`. [repeated 2x across cluster]
# (_ray_fit pid=4087) This will raise in a future version. [repeated 2x across cluster]
# (_ray_fit pid=4087)   warnings.warn(msg, FutureWarning) [repeated 2x across cluster]
# (_dystack pid=3341) 	0.3655	 = Validation score   (accuracy)
# (_dystack pid=3341) 	24.74s	 = Training   runtime
# (_dystack pid=3341) 	0.1s	 = Validation runtime
# (_dystack pid=3341) Fitting model: CatBoost_BAG_L1 ... Training model for up to 36.47s of the 82.99s of remaining time.
# (_dystack pid=3341) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.69%)
# (_dystack pid=3341) 	0.3931	 = Validation score   (accuracy)
# (_dystack pid=3341) 	40.35s	 = Training   runtime
# (_dystack pid=3341) 	0.24s	 = Validation runtime
# (_ray_fit pid=4085) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# (_ray_fit pid=4085) Dask dataframe query planning is disabled because dask-expr is not installed.
# (_ray_fit pid=4085)  [repeated 2x across cluster]
# (_ray_fit pid=4085) You can install it with `pip install dask[dataframe]` or `conda install dask`.
# (_ray_fit pid=4085) This will raise in a future version.
# (_ray_fit pid=4085)   warnings.warn(msg, FutureWarning)
# (_dystack pid=3341) Fitting model: WeightedEnsemble_L2 ... Training model for up to 139.5s of the 39.31s of remaining time.
# (_dystack pid=3341) 	Ensemble Weights: {'CatBoost_BAG_L1': 1.0}
# (_dystack pid=3341) 	0.3931	 = Validation score   (accuracy)
# (_dystack pid=3341) 	0.15s	 = Training   runtime
# (_dystack pid=3341) 	0.01s	 = Validation runtime
# (_dystack pid=3341) Fitting 6 L2 models ...
# (_dystack pid=3341) Fitting model: LightGBM_BAG_L2 ... Training model for up to 39.11s of the 39.06s of remaining time.
# (_dystack pid=3341) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.37%)
# (_ray_fit pid=4604) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# (_ray_fit pid=4604) Dask dataframe query planning is disabled because dask-expr is not installed.
# (_ray_fit pid=4604) You can install it with `pip install dask[dataframe]` or `conda install dask`.
# (_ray_fit pid=4604) This will raise in a future version.
# (_ray_fit pid=4604)   warnings.warn(msg, FutureWarning)
# (_ray_fit pid=4604)  [repeated 2x across cluster]
# (_ray_fit pid=4688) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:  [repeated 2x across cluster]
# (_ray_fit pid=4688) Dask dataframe query planning is disabled because dask-expr is not installed. [repeated 2x across cluster]
# (_ray_fit pid=4688) You can install it with `pip install dask[dataframe]` or `conda install dask`. [repeated 2x across cluster]
# (_ray_fit pid=4688) This will raise in a future version. [repeated 2x across cluster]
# (_ray_fit pid=4688)   warnings.warn(msg, FutureWarning) [repeated 2x across cluster]
# (_ray_fit pid=4688)  [repeated 4x across cluster]
# (_ray_fit pid=4767) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:  [repeated 2x across cluster]
# (_ray_fit pid=4767) Dask dataframe query planning is disabled because dask-expr is not installed. [repeated 2x across cluster]
# (_ray_fit pid=4767) You can install it with `pip install dask[dataframe]` or `conda install dask`. [repeated 2x across cluster]
# (_ray_fit pid=4767) This will raise in a future version. [repeated 2x across cluster]
# (_ray_fit pid=4767)   warnings.warn(msg, FutureWarning) [repeated 2x across cluster]
# (_ray_fit pid=4767)  [repeated 4x across cluster]
# (_ray_fit pid=4858) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:  [repeated 2x across cluster]
# (_ray_fit pid=4858) Dask dataframe query planning is disabled because dask-expr is not installed. [repeated 2x across cluster]
# (_ray_fit pid=4858) You can install it with `pip install dask[dataframe]` or `conda install dask`. [repeated 2x across cluster]
# (_ray_fit pid=4858) This will raise in a future version. [repeated 2x across cluster]
# (_ray_fit pid=4858)   warnings.warn(msg, FutureWarning) [repeated 2x across cluster]
# (_ray_fit pid=4858)  [repeated 4x across cluster]
# (_dystack pid=3341) 	0.3747	 = Validation score   (accuracy)
# (_dystack pid=3341) 	24.59s	 = Training   runtime
# (_dystack pid=3341) 	0.08s	 = Validation runtime
# (_dystack pid=3341) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 10.49s of the 10.45s of remaining time.
# (_dystack pid=3341) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.37%)
# (_ray_fit pid=4946) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:  [repeated 2x across cluster]
# (_ray_fit pid=4946) Dask dataframe query planning is disabled because dask-expr is not installed. [repeated 2x across cluster]
# (_ray_fit pid=4946) You can install it with `pip install dask[dataframe]` or `conda install dask`. [repeated 2x across cluster]
# (_ray_fit pid=4946) This will raise in a future version. [repeated 2x across cluster]
# (_ray_fit pid=4946)   warnings.warn(msg, FutureWarning) [repeated 2x across cluster]
# (_ray_fit pid=4946)  [repeated 4x across cluster]
# (_ray_fit pid=5034) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:  [repeated 2x across cluster]
# (_ray_fit pid=5034) Dask dataframe query planning is disabled because dask-expr is not installed. [repeated 2x across cluster]
# (_ray_fit pid=5034) You can install it with `pip install dask[dataframe]` or `conda install dask`. [repeated 2x across cluster]
# (_ray_fit pid=5034) This will raise in a future version. [repeated 2x across cluster]
# (_ray_fit pid=5034)   warnings.warn(msg, FutureWarning) [repeated 2x across cluster]
# (_ray_fit pid=5034)  [repeated 4x across cluster]
# (_ray_fit pid=5116) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:  [repeated 2x across cluster]
# (_ray_fit pid=5116) Dask dataframe query planning is disabled because dask-expr is not installed. [repeated 2x across cluster]
# (_ray_fit pid=5116) You can install it with `pip install dask[dataframe]` or `conda install dask`. [repeated 2x across cluster]
# (_ray_fit pid=5116) This will raise in a future version. [repeated 2x across cluster]
# (_ray_fit pid=5116)   warnings.warn(msg, FutureWarning) [repeated 2x across cluster]
# (_ray_fit pid=5116)  [repeated 4x across cluster]
# (_ray_fit pid=5209) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:  [repeated 2x across cluster]
# (_ray_fit pid=5209) Dask dataframe query planning is disabled because dask-expr is not installed. [repeated 2x across cluster]
# (_ray_fit pid=5209) You can install it with `pip install dask[dataframe]` or `conda install dask`. [repeated 2x across cluster]
# (_ray_fit pid=5209) This will raise in a future version. [repeated 2x across cluster]
# (_ray_fit pid=5209)   warnings.warn(msg, FutureWarning) [repeated 2x across cluster]
# (_ray_fit pid=5209)  [repeated 4x across cluster]
# (_dystack pid=3341) 	0.3701	 = Validation score   (accuracy)
# (_dystack pid=3341) 	23.39s	 = Training   runtime
# (_dystack pid=3341) 	0.1s	 = Validation runtime
# (_dystack pid=3341) Fitting model: WeightedEnsemble_L3 ... Training model for up to 139.5s of the -17.9s of remaining time.
# (_dystack pid=3341) 	Ensemble Weights: {'CatBoost_BAG_L1': 1.0}
# (_dystack pid=3341) 	0.3931	 = Validation score   (accuracy)
# (_dystack pid=3341) 	0.06s	 = Training   runtime
# (_dystack pid=3341) 	0.0s	 = Validation runtime
# (_dystack pid=3341) AutoGluon training complete, total runtime = 159.19s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 225.7 rows/s (55 batch size)
# (_dystack pid=3341) Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# (_dystack pid=3341) Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# (_dystack pid=3341) 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# (_dystack pid=3341) 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# (_dystack pid=3341) 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# (_dystack pid=3341) Fitting 1 L1 models ...
# (_dystack pid=3341) Fitting model: LightGBM_BAG_L1_FULL ...
# (_dystack pid=3341) 	1.86s	 = Training   runtime
# (_dystack pid=3341) Fitting 1 L1 models ...
# (_dystack pid=3341) Fitting model: LightGBMXT_BAG_L1_FULL ...
# (_dystack pid=3341) 	0.52s	 = Training   runtime
# (_dystack pid=3341) Fitting 1 L1 models ...
# (_dystack pid=3341) Fitting model: CatBoost_BAG_L1_FULL ...
# (_dystack pid=3341) 	1.25s	 = Training   runtime
# (_dystack pid=3341) Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=3341) 	Ensemble Weights: {'CatBoost_BAG_L1': 1.0}
# (_dystack pid=3341) 	0.15s	 = Training   runtime
# (_dystack pid=3341) Fitting 1 L2 models ...
# (_dystack pid=3341) Fitting model: LightGBM_BAG_L2_FULL ...
# (_dystack pid=3341) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:  [repeated 2x across cluster]
# (_dystack pid=3341) Dask dataframe query planning is disabled because dask-expr is not installed. [repeated 2x across cluster]
# (_dystack pid=3341) You can install it with `pip install dask[dataframe]` or `conda install dask`. [repeated 2x across cluster]
# (_dystack pid=3341) This will raise in a future version. [repeated 2x across cluster]
# (_dystack pid=3341)   warnings.warn(msg, FutureWarning) [repeated 2x across cluster]
# (_dystack pid=3341)  [repeated 4x across cluster]
# (_dystack pid=3341) 	0.31s	 = Training   runtime
# (_dystack pid=3341) Fitting 1 L2 models ...
# (_dystack pid=3341) Fitting model: LightGBMXT_BAG_L2_FULL ...
# (_dystack pid=3341) 	0.49s	 = Training   runtime
# (_dystack pid=3341) Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# (_dystack pid=3341) 	Ensemble Weights: {'CatBoost_BAG_L1': 1.0}
# (_dystack pid=3341) 	0.06s	 = Training   runtime
# (_dystack pid=3341) Updated best model to "CatBoost_BAG_L1_FULL" (Previously "WeightedEnsemble_L2"). AutoGluon will default to using "CatBoost_BAG_L1_FULL" for predict() and predict_proba().
# (_dystack pid=3341) Refit complete, total runtime = 4.76s ... Best model: "CatBoost_BAG_L1_FULL"
# (_dystack pid=3341) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20240930_231941/ds_sub_fit/sub_fit_ho")
# (_dystack pid=3341) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test pred_time_val  fit_time  pred_time_test_marginal pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      CatBoost_BAG_L1_FULL       0.339286   0.393103    accuracy        0.031209          None  1.252613                 0.031209                   None           1.252613            1       True          3
# 1  WeightedEnsemble_L3_FULL       0.339286   0.393103    accuracy        0.033085          None  1.314972                 0.001876                   None           0.062359            3       True          7
# 2  WeightedEnsemble_L2_FULL       0.339286   0.393103    accuracy        0.033269          None  1.399880                 0.002060                   None           0.147267            2       True          4
# 3      LightGBM_BAG_L2_FULL       0.339286   0.374713    accuracy        0.109022          None  3.943246                 0.018785                   None           0.310814            2       True          5
# 4      LightGBM_BAG_L1_FULL       0.321429   0.377011    accuracy        0.017667          None  1.862640                 0.017667                   None           1.862640            1       True          1
# 5    LightGBMXT_BAG_L1_FULL       0.321429   0.365517    accuracy        0.041361          None  0.517179                 0.041361                   None           0.517179            1       True          2
# 6    LightGBMXT_BAG_L2_FULL       0.321429   0.370115    accuracy        0.129054          None  4.127300                 0.038817                   None           0.494869            2       True          6
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	178s	 = DyStack   runtime |	422s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 422s
# AutoGluon will save models to "AutogluonModels/ag-20240930_231941"
# Train Data Rows:    500
# Train Data Columns: 24
# Label Column:       AdoptionSpeed
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 5
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    10869.94 MB
# 	Train Data (Original)  Memory Usage: 0.44 MB (0.0% of available memory)
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting IdentityFeatureGenerator...
# 			Fitting RenameFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting TextSpecialFeatureGenerator...
# 			Fitting BinnedFeatureGenerator...
# 			Fitting DropDuplicatesFeatureGenerator...
# 		Fitting TextNgramFeatureGenerator...
# 			Fitting CountVectorizer for text features: ['Description']
# 			CountVectorizer fit with vocabulary size = 170
# 		Fitting IdentityFeatureGenerator...
# 		Fitting IsNanFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['PetID']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', []) : 1 | ['PetID']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])              :  1 | ['PhotoAmt']
# 		('int', [])                : 18 | ['Type', 'Age', 'Breed1', 'Breed2', 'Gender', ...]
# 		('object', [])             :  2 | ['Name', 'RescuerID']
# 		('object', ['image_path']) :  1 | ['Images']
# 		('object', ['text'])       :  1 | ['Description']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])                    :   2 | ['Name', 'RescuerID']
# 		('category', ['text_as_category'])  :   1 | ['Description']
# 		('float', [])                       :   1 | ['PhotoAmt']
# 		('int', [])                         :  17 | ['Age', 'Breed1', 'Breed2', 'Gender', 'Color1', ...]
# 		('int', ['binned', 'text_special']) :  24 | ['Description.char_count', 'Description.word_count', 'Description.capital_ratio', 'Description.lower_ratio', 'Description.digit_ratio', ...]
# 		('int', ['bool'])                   :   1 | ['Type']
# 		('int', ['text_ngram'])             : 171 | ['__nlp__.about', '__nlp__.active', '__nlp__.active and', '__nlp__.adopt', '__nlp__.adopted', ...]
# 		('object', ['image_path'])          :   1 | ['Images']
# 		('object', ['text'])                :   1 | ['Description_raw_text']
# 	3.2s = Fit runtime
# 	23 features in original data used to generate 219 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.51 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 3.26s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{}, {'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'AG_AUTOMM': {},
# 	'VW': {},
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 8 L1 models ...
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 278.92s of the 418.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.39%)
# 	0.38	 = Validation score   (accuracy)
# 	27.24s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 249.02s of the 388.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.40%)
# 	0.362	 = Validation score   (accuracy)
# 	25.68s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 220.13s of the 359.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.80%)
# 	0.386	 = Validation score   (accuracy)
# 	104.29s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 112.59s of the 252.16s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.79%)
# 	0.362	 = Validation score   (accuracy)
# 	25.29s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 84.19s of the 223.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.354	 = Validation score   (accuracy)
# 	46.43s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Fitting model: VowpalWabbit_BAG_L1 ... Training model for up to 34.85s of the 174.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	Warning: Exception caused VowpalWabbit_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=7552, ip=172.28.0.12)
# ModuleNotFoundError: No module named 'vowpalwabbit'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=7552, ip=172.28.0.12)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/vowpalwabbit/vowpalwabbit_model.py", line 68, in _fit
#     try_import_vowpalwabbit()
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/common/utils/try_import.py", line 173, in try_import_vowpalwabbit
#     raise ImportError("`import vowpalwabbit` failed.\n" "A quick tip is to install via `pip install vowpalwabbit>=9,<9.10")
# ImportError: `import vowpalwabbit` failed.
# A quick tip is to install via `pip install vowpalwabbit>=9,<9.10
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 31.09s of the 170.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.53%)
# 2024-09-30 23:26:56,596	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.4	 = Validation score   (accuracy)
# 	40.48s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 125.86s of remaining time.
# 	Ensemble Weights: {'LightGBMLarge_BAG_L1': 1.0}
# 	0.4	 = Validation score   (accuracy)
# 	0.09s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 6 L2 models ...
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 125.75s of the 125.73s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.46%)
# 	0.378	 = Validation score   (accuracy)
# 	33.24s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 86.54s of the 86.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.46%)
# 	0.374	 = Validation score   (accuracy)
# 	27.64s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 55.66s of the 55.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.91%)
# 	0.404	 = Validation score   (accuracy)
# 	53.35s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -1.01s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L2': 1.0}
# 	0.404	 = Validation score   (accuracy)
# 	0.21s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 423.02s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 48.3 rows/s (63 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# 	1.53s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	0.3s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	2.47s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	0.41s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	1.46s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	0.93s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'LightGBMLarge_BAG_L1': 1.0}
# 	0.09s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBM_BAG_L2_FULL ...
# 	0.78s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBMXT_BAG_L2_FULL ...
# 	0.5s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: CatBoost_BAG_L2_FULL ...
# 	2.25s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'CatBoost_BAG_L2': 1.0}
# 	0.21s	 = Training   runtime
# Updated best model to "CatBoost_BAG_L2_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "CatBoost_BAG_L2_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 12.95s ... Best model: "CatBoost_BAG_L2_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20240930_231941")

# %%
predictor.evaluate(test_data, silent=True)
# Out:
# {'accuracy': 0.3564521507169056,
#  'balanced_accuracy': 0.2631334432900726,
#  'mcc': 0.12936967741380828}

# %%
predictor.leaderboard(test_data)
# Out:
#                          model  score_test  score_val eval_metric  \
# 0         CatBoost_BAG_L2_FULL    0.356452        NaN    accuracy
# 1     WeightedEnsemble_L3_FULL    0.356452        NaN    accuracy
# 2       LightGBMXT_BAG_L2_FULL    0.351117        NaN    accuracy
# 3         LightGBM_BAG_L2_FULL    0.342447        NaN    accuracy
# 4         CatBoost_BAG_L1_FULL    0.334445        NaN    accuracy
# 5         LightGBM_BAG_L1_FULL    0.327776        NaN    accuracy
# 6   NeuralNetTorch_BAG_L1_FULL    0.323775        NaN    accuracy
# 7          XGBoost_BAG_L1_FULL    0.322107        NaN    accuracy
# 8       LightGBMXT_BAG_L1_FULL    0.317439        NaN    accuracy
# 9    LightGBMLarge_BAG_L1_FULL    0.308103        NaN    accuracy
# 10    WeightedEnsemble_L2_FULL    0.308103        NaN    accuracy
# 11             CatBoost_BAG_L2         NaN      0.404    accuracy
# 12         WeightedEnsemble_L3         NaN      0.404    accuracy
# 13        LightGBMLarge_BAG_L1         NaN      0.400    accuracy
# 14         WeightedEnsemble_L2         NaN      0.400    accuracy
# 15             CatBoost_BAG_L1         NaN      0.386    accuracy
# 16             LightGBM_BAG_L1         NaN      0.380    accuracy
# 17             LightGBM_BAG_L2         NaN      0.378    accuracy
# 18           LightGBMXT_BAG_L2         NaN      0.374    accuracy
# 19           LightGBMXT_BAG_L1         NaN      0.362    accuracy
# 20              XGBoost_BAG_L1         NaN      0.362    accuracy
# 21       NeuralNetTorch_BAG_L1         NaN      0.354    accuracy
#
#     pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 0         0.351451            NaN    9.358225                 0.023501
# 1         0.353110            NaN    9.564215                 0.001659
# 2         0.352569            NaN    7.606152                 0.024619
# 3         0.375468            NaN    7.882043                 0.047518
# 4         0.027041            NaN    2.468017                 0.027041
# 5         0.071068            NaN    1.530799                 0.071068
# 6         0.047226            NaN    1.463800                 0.047226
# 7         0.061657            NaN    0.410833                 0.061657
# 8         0.061069            NaN    0.299435                 0.061069
# 9         0.059889            NaN    0.931151                 0.059889
# 10        0.061729            NaN    1.019727                 0.001840
# 11             NaN       1.304040  322.752192                      NaN
# 12             NaN       1.307296  322.958182                      NaN
# 13             NaN       0.117296   40.478320                      NaN
# 14             NaN       0.118467   40.566895                      NaN
# 15             NaN       0.168397  104.286792                      NaN
# 16             NaN       0.081239   27.236676                      NaN
# 17             NaN       1.241263  302.644225                      NaN
# 18             NaN       1.233235  297.046901                      NaN
# 19             NaN       0.078056   25.679602                      NaN
# 20             NaN       0.123204   25.293565                      NaN
# 21             NaN       0.548498   46.432065                      NaN
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                      NaN           2.254191            2       True
# 1                      NaN           0.205990            3       True
# 2                      NaN           0.502118            2       True
# 3                      NaN           0.778009            2       True
# 4                      NaN           2.468017            1       True
# 5                      NaN           1.530799            1       True
# 6                      NaN           1.463800            1       True
# 7                      NaN           0.410833            1       True
# 8                      NaN           0.299435            1       True
# 9                      NaN           0.931151            1       True
# 10                     NaN           0.088576            2       True
# 11                0.187351          53.345172            2      False
# 12                0.003256           0.205990            3      False
# 13                0.117296          40.478320            1      False
# 14                0.001171           0.088576            2      False
# 15                0.168397         104.286792            1      False
# 16                0.081239          27.236676            1      False
# 17                0.124574          33.237205            2      False
# 18                0.116545          27.639881            2      False
# 19                0.078056          25.679602            1      False
# 20                0.123204          25.293565            1      False
# 21                0.548498          46.432065            1      False
#
#     fit_order
# 0          21
# 1          22
# 2          20
# 3          19
# 4          14
# 5          12
# 6          16
# 7          15
# 8          13
# 9          17
# 10         18
# 11         10
# 12         11
# 13          6
# 14          7
# 15          3
# 16          1
# 17          8
# 18          9
# 19          2
# 20          4
# 21          5
